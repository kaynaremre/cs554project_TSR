# %%
import numpy as np
import pandas as pd
from PIL import Image

# %%
annotations_file = 'annotations_split.csv'

# %%
anno = pd.read_csv(annotations_file)
anno.head()
# Out:
#                       filename   x1   y1   x2   y2 class Train/Test
# 0  db_lisa_tiny/sample_001.png  190   40  211   63  stop      Train
# 1  db_lisa_tiny/sample_002.png    4  246   43  283  stop      Train
# 2  db_lisa_tiny/sample_003.png  389  286  418  314  stop      Train
# 3  db_lisa_tiny/sample_004.png  307  243  315  251  stop      Train
# 4  db_lisa_tiny/sample_005.png  377  249  398  270  stop      Train

# %%
# Get filenames from annotations file and get size of each image

width_list = []
height_list = []

filename = []
x1 = []
y1 = []
x2 = []
y2 = []
classes = []


for i in anno["filename"]:
    image = Image.open(i)

    width, height = image.size
    
    if (width!=704):
        width_list.append(width)
        height_list.append(height)

# Insert width and height of images to annotations data frame
anno['width'] = width_list
anno['height'] = height_list

anno.head()
# Out:
#                       filename   x1   y1   x2   y2 class Train/Test  width  \
# 0  db_lisa_tiny/sample_001.png  190   40  211   63  stop      Train    704
# 1  db_lisa_tiny/sample_002.png    4  246   43  283  stop      Train    704
# 2  db_lisa_tiny/sample_003.png  389  286  418  314  stop      Train    704
# 3  db_lisa_tiny/sample_004.png  307  243  315  251  stop      Train    640
# 4  db_lisa_tiny/sample_005.png  377  249  398  270  stop      Train    640
#
#    height
# 0     480
# 1     480
# 2     480
# 3     480
# 4     480

# %%
annos = anno[anno['width'] > 650] 
annos
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'width'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-47ecab0a08b9> in <module>
# ----> 1 annos = anno[anno['width'] > 650]
#       2 annos
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'width'

# %%
# Save dataframe as csv file
anno.to_csv("annotations_imSize.csv", index=False)
